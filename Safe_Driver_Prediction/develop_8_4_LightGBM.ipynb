# %% [markdown]
# ## 8.4 성능개선 I: LightGBM 모델

# %%
import pandas as pd

data_path = './data/'

train = pd.read_csv(data_path + "train.csv", index_col = "id")
test = pd.read_csv(data_path + "test.csv", index_col = "id")
submission = pd.read_csv(data_path + "sample_submission.csv", index_col = "id")

# %% [markdown]
# ### 8.4.1 피처 엔지니어링

# %%
# 데이터 합치기 
all_data = pd.concat([train, test], ignore_index=True)
all_data = all_data.drop("target", axis=1)  # drop target

all_features = all_data.columns  # 전체 features

# %%
# 명목형 피처 원-핫 인코딩
from sklearn.preprocessing import OneHotEncoder

# categorical features 
cat_features = [feature for feature in all_features if "cat" in feature]

# one-hot encoding 
onehot_encoder = OneHotEncoder()
encoded_cat_matrix = onehot_encoder.fit_transform(all_data[cat_features])

# %%
# 파생 피쳐 추가 

# 데이터 하나당 결측치 개수를 파생 피처로 추가 
all_data["num_missing"] = (all_data==1).sum(axis=1)
all_data.head()
# Out:
#    ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  \
# 0          2              2          5              1              0
# 1          1              1          7              0              0
# 2          5              4          9              1              0
# 3          0              1          2              0              0
# 4          0              2          0              1              0
#
#    ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ps_ind_09_bin  ps_ind_10_bin  \
# 0              0              1              0              0              0
# 1              0              0              1              0              0
# 2              0              0              1              0              0
# 3              1              0              0              0              0
# 4              1              0              0              0              0
#
#    ...  ps_calc_12  ps_calc_13  ps_calc_14  ps_calc_15_bin  ps_calc_16_bin  \
# 0  ...           1           5           8               0               1
# 1  ...           1           1           9               0               1
# 2  ...           2           7           7               0               1
# 3  ...           2           4           9               0               0
# 4  ...           1           1           3               0               0
#
#    ps_calc_17_bin  ps_calc_18_bin  ps_calc_19_bin  ps_calc_20_bin  num_missing
# 0               1               0               0               1           14
# 1               1               0               1               0           15
# 2               1               0               1               0           12
# 3               0               0               0               0           10
# 4               0               1               1               0           11
#
# [5 rows x 58 columns]
